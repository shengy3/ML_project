# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
raw_data = genfromtxt('signal.csv', delimiter=',')

# %%
df = pd.DataFrame(raw_data)

# %%
plt.plot(df.iloc[0,:])
plt.xlabel("channel")
plt.ylabel("adc value")
#plt.xlim([0,300])
# Out:
# Text(0,0.5,'adc value')

# %%
#df.head()
df.iloc[0, 0:70].std()
# Out:
# 1.1870732152067933

# %%
select_df = df.iloc[0,:]#df[df.iloc[0,:] >df.iloc[0, 0:70].std()]
new_select_df = select_df[select_df > 2* df.iloc[0, 0:70].std()]#df.iloc[0,:]
plt.plot(new_select_df)
plt.show()

# %%
from sklearn.ensemble import IsolationForest
import numpy as np
X = df.iloc[0,:]#np.array([[-1, -1], [-2, -1], [-3, -2], [0, 0], [-20, 50], [3, 5]])
clf = IsolationForest(n_estimators=10)
clf.fit(X)  # fit 10 trees  
clf.set_params(n_estimators=20)  # add 10 more trees  
clf.fit(X)  # fit the added trees
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e58178aa6c0d> in <module>()
#       3 X = df.iloc[0,:]#np.array([[-1, -1], [-2, -1], [-3, -2], [0, 0], [-20, 50], [3, 5]])
#       4 clf = IsolationForest(n_estimators=10)
# ----> 5 clf.fit(X)  # fit 10 trees
#       6 clf.set_params(n_estimators=20)  # add 10 more trees
#       7 clf.fit(X)  # fit the added trees
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py in fit(self, X, y, sample_weight)
#     160             Returns self.
#     161         """
# --> 162         X = check_array(X, accept_sparse=['csc'])
#     163         if issparse(X):
#     164             # Pre-sort indices to avoid that each individual tree of the
#
# ...
